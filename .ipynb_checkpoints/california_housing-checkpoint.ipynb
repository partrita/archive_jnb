# %% [markdown]
# # 필요한 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import os
import tarfile
from six.moves import urllib
import matplotlib.pyplot as plt

# 난수 초기화
np.random.seed(42)

# 맷플롯립 설정
# %matplotlib inline

# %% [markdown]
# # 데이터 다운로드

# %%
# DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml/master/"
# HOUSING_PATH = os.path.join("input", "housing")
# HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"

# def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
#     if not os.path.isdir(housing_path):
#         os.makedirs(housing_path)
#     tgz_path = os.path.join(housing_path, "housing.tgz")
#     urllib.request.urlretrieve(housing_url, tgz_path)
#     housing_tgz = tarfile.open(tgz_path)
#     housing_tgz.extractall(path=housing_path)
#     housing_tgz.close()
    
# fetch_housing_data()

# %% [markdown]
# # pandas 데이터 불러오기

# %%
housing = pd.read_csv('./input/housing/housing.csv')
housing.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %% [markdown]
# # EDA 하기

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# 히스토그램을 그려 봅시다.

# %%
fig = housing.hist(bins=50, figsize=(20,15))

# %% [markdown]
# 지리적 데이터 시각화

# %%
import matplotlib.image as mpimg
california_img=mpimg.imread('./input/housing/california.png')
ax = housing.plot(kind="scatter", x="longitude", y="latitude", figsize=(10,7),
                       s=housing['population']/100, label="population",
                       c="median_house_value", cmap=plt.get_cmap(),
                       colorbar=False, alpha=0.4,
                      )
plt.imshow(california_img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.2)
prices = housing["median_house_value"]
tick_values = np.linspace(prices.min(), prices.max(), 11)
cbar = plt.colorbar()
cbar.ax.set_yticklabels(["$%dk"%(round(v/1000)) for v in tick_values], fontsize=14)
plt.show()

# %% [markdown]
# 상관관계 조사
#
# 숫자형 특성이 11개이므로 총 121개의 그래프가 되어 너무 많음으로, 중간 주택가격과 상관관계가 높아 보이는 특성 몇개 만 살펴봅니다.

# %%
from pandas.tools.plotting import scatter_matrix

corr_matrix = housing.corr()
attributes = ['median_house_value','median_income', 'total_rooms','housing_median_age']
fig = scatter_matrix(housing[attributes], figsize = (10,10), alpha = 0.2)

# %% [markdown]
# 중간 소득이 중간 주택 가격을 예측하는데 가장 유용할 것으로 가정하고 산점도를 다시 크게 그려보겠습니다.

# %%
housing.plot(kind="scatter", x="median_income", y="median_house_value",
             alpha=0.1)
plt.axis([0, 16, 0, 550000])
# Out:
# [0, 16, 0, 550000]

# %%
housing["rooms_per_household"] = housing["total_rooms"]/housing["households"]
housing["bedrooms_per_room"] = housing["total_bedrooms"]/housing["total_rooms"]
housing["population_per_household"]=housing["population"]/housing["households"]

# %%
housing.plot(kind="scatter", x="rooms_per_household", y="median_house_value",
             alpha=0.2)
plt.axis([0, 5, 0, 520000])
plt.show()

# %% [markdown]
# # 머신러닝을 위한
#
# 데이터 삭제

# %%
housing_labels = housing["median_house_value"].copy()
housing.drop("median_house_value", axis=1, inplace = True) # 훈련 세트를 위해 레이블 삭제

# %% [markdown]
# ## 테스트세트 만들기
# ### 무작위로 샘플링

# %%
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(housing, test_size=0.2, random_state=42)
print(X_train.shape, X_test.shape)
# Out:
# (16512, 10) (4128, 10)

# %% [markdown]
# ### 계층적 샘플링

# %%
# from sklearn.model_selection import StratifiedShuffleSplit

# split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
# for train_index, test_index in split.split(housing, housing["median_income"]):
#     strat_train_set = housing.loc[train_index]
#     strat_test_set = housing.loc[test_index]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-4a0fbcff788c> in <module>()
#       2
#       3 split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
# ----> 4 for train_index, test_index in split.split(housing, housing["median_income"]):
#       5     strat_train_set = housing.loc[train_index]
#       6     strat_test_set = housing.loc[test_index]
#
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#     951         """
#     952         X, y, groups = indexable(X, y, groups)
# --> 953         for train, test in self._iter_indices(X, y, groups):
#     954             yield train, test
#     955
#
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_split.py in _iter_indices(self, X, y, groups)
#    1257         class_counts = bincount(y_indices)
# ...

# %% [markdown]
# 데이터 준비
# 데이터 정제
# ㅠ

# %%
from sklearn.preprocessing import Imputer

imputer = Imputer(strategy="median")

housing_num = housing.drop('ocean_proximity', axis=1)
# 다른 방법: housing_num = housing.select_dtypes(include=[np.number])
imputer.fit(housing_num)
X = imputer.transform(housing_num)
housing_tr = pd.DataFrame(X, columns=housing_num.columns)
housing_tr.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  rooms_per_household  \
# 0       322.0       126.0         8.3252             6.984127
# 1      2401.0      1138.0         8.3014             6.238137
# 2       496.0       177.0         7.2574             8.288136
# 3       558.0       219.0         5.6431             5.817352
# 4       565.0       259.0         3.8462             6.281853
#
#    bedrooms_per_room  population_per_household
# 0           0.146591                  2.555556
# 1           0.155797                  2.109842
# ...

# %% [markdown]
# 이이제 범주형 이터 전처리

# %%
housing_cat = housing['ocean_proximity']
housing_cat_encoded, housing_categories = housing_cat.factorize()
# 판다스의 factorize() 메소드는 문자열 범주형 특성을 머신러닝 알고리즘이 다루기 쉬운 숫자 범주형 특성으로 변환시켜 줍니다:
from  sklearn.preprocessingsklearn.  import OneHotEncoder
#OneHotEncoder를 사용하여 범주형 값을 원-핫 벡터로 변경합니다:
encoder = OneHotEncoder()
housing_cat_1hot = encoder.fit_transform(housing_cat_encoded.reshape(-1,1))
# Out:
#   File "<ipython-input-51-5c8ab5529f6c>", line 4
#     fromfrom  sklearn.preprocessingsklearn.  import OneHotEncoder
#                     ^
# SyntaxError: invalid syntax
