# %%
file = 'naname.xlsx'
import pandas as pd

df = pd.read_excel(file, encoding= 'cp949')

# %%
df.tail()
# Out:
#        연도 연도/월  Itm   상태 G/L 계정  계정명   참조   지정  BP   유형 ...   전기일 현지통화액  L통화  \
# 85289 NaN  NaN  NaN  NaN    NaN  NaN  NaN  NaN NaN  NaN ...   NaT   NaN  NaN
# 85290 NaN  NaN  NaN  NaN    NaN  NaN  NaN  NaN NaN  NaN ...   NaT   NaN  NaN
# 85291 NaN  NaN  NaN  NaN    NaN  NaN  NaN  NaN NaN  NaN ...   NaT   NaN  NaN
# 85292 NaN  NaN  NaN  NaN    NaN  NaN  NaN  NaN NaN  NaN ...   NaT   NaN  NaN
# 85293 NaN  NaN  NaN  NaN    NaN  NaN  NaN  NaN NaN  NaN ...   NaT   NaN  NaN
#
#        반제일 증빙일 순만기일        수량  BUn  전표통화액   통화
# 85289  NaT NaT  NaN       NaN  NaN    NaN  NaN
# 85290  NaT NaT  NaN       NaN  NaN    NaN  NaN
# 85291  NaT NaT  NaN  660000.0  NaN    NaN  NaN
# 85292  NaT NaT  NaN  528000.0  NaN    NaN  NaN
# 85293  NaT NaT  NaN  528000.0  NaN    NaN  NaN
#
# [5 rows x 48 columns]

# %%
df.head()
# Out:
#        연도     연도/월  Itm        상태    G/L 계정              계정명   참조        지정  \
# 0  2015.0  2015/01  1.0  @5B\Q반제@  21113100          예수금_소득세  김상덕  20150112
# 1  2015.0  2015/01  2.0  @5B\Q반제@  21113100          예수금_소득세  김상덕  20150112
# 2  2015.0  2015/01  3.0  @5B\Q반제@  21113110          예수금_주민세  김상덕  20150112
# 3  2015.0  2015/01  4.0  @5B\Q반제@  21113110          예수금_주민세  김상덕  20150112
# 4  2015.0  2015/12  1.0  @5B\Q반제@  12107100  보증금_임차보증금(건물임차)  NaN  20151231
#
#        BP  유형 ...         전기일       현지통화액  L통화        반제일        증빙일 순만기일  \
# 0     NaN  AB ...  2015-01-12  24142920.0  KRW 2015-01-12 2015-01-12  NaN
# 1  1700.0  AB ...  2015-01-12 -24142920.0  KRW 2015-01-12 2015-01-12  NaN
# 2     NaN  AB ...  2015-01-12   2413970.0  KRW 2015-01-12 2015-01-12  NaN
# 3  1700.0  AB ...  2015-01-12  -2413970.0  KRW 2015-01-12 2015-01-12  NaN
# 4     NaN  AB ...  2015-12-31  -3000000.0  KRW 2015-12-31 2015-12-31  NaN
#
#     수량  BUn       전표통화액   통화
# 0  0.0  NaN  24142920.0  KRW
# ...

# %%
df.iloc[12301]
# Out:
# 연도                             2015
# 연도/월                        2015/02
# Itm                               2
# 상태                         @01\Q전기@
# G/L 계정                     46133201
# 계정명                   (수익)특정연구비_인건비
# 참조                              이성규
# 지정                       0017100000
# BP                              NaN
# 유형                               ZD
# PK                               40
# D/C                               S
# SG                              NaN
# PayT                            NaN
# NP                              NaN
# Tx                              NaN
# 텍스트          AI백신 내부 인건비 대체(15년 2월)
# 전표 번호                       8.7e+09
# 취소                              NaN
# 반제전표                            NaN
# 참조 키 1                          NaN
# 참조 키 2                          NaN
# 참조키 3                           NaN
# 송장 참조                       8.7e+09
# 전표 헤더 텍스트            AI백신 내부 인건비 대체
# BusA                           1730
# ...
