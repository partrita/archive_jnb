# %%
import pandas as pd
import seaborn as sns

# %%
colnames=['Name', 'Department', 'E-mail','Z'] 
df = pd.read_csv('./data/unemployed.csv', names=colnames, header=None)
df.tail()
# Out:
#     Name Department                    E-mail   Z
# 359  박민지      환경공학부     pmj7907@postech.ac.kr NaN
# 360  이현숙        화학과    hyunsook@postech.ac.kr NaN
# 361  윤종섭      기계공학과  whdtjq4144@postech.ac.kr NaN
# 362  류연종      기계공학과    jong8272@postech.ac.kr NaN
# 363  홍순호     신소재공학과    soonho30@postech.ac.kr NaN

# %%
ax = sns.countplot(y="Department", data=df)

# %%
df2 = df.groupby(['Department']).size().reset_index() 
df2.columns = ['Department','Count']

# %%
df2
# Out:
#         Department  Count
# 0            기계공학과     27
# 1             물리학과     16
# 2          산업경영공학과     15
# 3            생명과학과     64
# 4              수학과     36
# 5         시스템생명공학부      4
# 6           신소재공학과     17
# 7        엔지니어링 대학원      2
# 8          융합생명공학부      7
# 9          전자전기공학과     41
# 10       정보전자융합공학부      4
# 11          정보통신학과      7
# 12       창의IT융합공학과      8
# 13           철강대학원      1
# 14            철강학과      2
# 15        첨단원자력공학부      1
# 16         첨단재료과학부      3
# 17          컴퓨터공학과     36
# 18       풍력특성화협동과정      1
# 19  플랜트시스템 엔지니어링학과      9
# 20            해양학과      3
# 21           화학공학과     11
# 22             화학과     41
# 23           환경공학부      8

# %%
df2.sort_values(by=['Count'], ascending=False )
# Out:
#         Department  Count
# 3            생명과학과     64
# 22             화학과     41
# 9          전자전기공학과     41
# 4              수학과     36
# 17          컴퓨터공학과     36
# 0            기계공학과     27
# 6           신소재공학과     17
# 1             물리학과     16
# 2          산업경영공학과     15
# 21           화학공학과     11
# 19  플랜트시스템 엔지니어링학과      9
# 12       창의IT융합공학과      8
# 23           환경공학부      8
# 11          정보통신학과      7
# 8          융합생명공학부      7
# 10       정보전자융합공학부      4
# 5         시스템생명공학부      4
# 16         첨단재료과학부      3
# 20            해양학과      3
# 14            철강학과      2
# 7        엔지니어링 대학원      2
# 13           철강대학원      1
# 15        첨단원자력공학부      1
# 18       풍력특성화협동과정      1
