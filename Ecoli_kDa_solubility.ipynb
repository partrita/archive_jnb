# %% [markdown]
# <a href="https://colab.research.google.com/github/partrita/JupyterNote/blob/master/Ecoli_kDa_solubility.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google colab을 이용한 주피터 노트북
#
# 연습용

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-627d30ca-064d-4559-837b-af7a5098d351" name="files[]" multiple disabled />
#      <output id="result-627d30ca-064d-4559-837b-af7a5098d351">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving all_data.tab to all_data.tab

# %%
import pandas as pd

df = pd.read_csv('all_data.tab', sep='\t')
df.head()
# Out:
#     JW_ID  ...                                    SCOP assignment
# 0  JW0002  ...  54211; Ribosomal protein S5 domain 2-like 5506...
# 1  JW0003  ...  53686; Tryptophan synthase beta subunit-like P...
# 2  JW0004  ...                                                NaN
# 3  JW0005  ...                                                NaN
# 4  JW0007  ...                                    51569; Aldolase
#
# [5 rows x 28 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# plt.plot(df['Solubility(%)'])
sns.set(rc={'figure.figsize':(10,10)})

sns.scatterplot(y='Solubility(%)',
                x="Calculated MW(kDa)",
                linewidth=0.1,
                alpha=0.5,
                sizes=(1,8),
                data=df)
