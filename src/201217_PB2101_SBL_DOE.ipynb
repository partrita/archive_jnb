# %%
import pandas as pd

df = pd.read_csv('1217_PB101_SBL_2ed_DOE.csv')
df.head()
# Out:
#    Run  Wash_AmSo4(M)  Elution pH  Elution_AmSo4(M)  Load amount(mg)  \
# 0    1            0.6           6               0.6           102.63
# 1    2            0.8           7               0.2           102.66
# 2    3            0.6           7               0.4           102.66
# 3    4            0.8           7               0.4           102.66
# 4    5            1.0           7               0.4           102.66
#
#    Elute_conc(mg/ml)  Elute_volume(ml)  Elute_volume(CV)  Elute_amount(mg)  \
# 0               0.32             24.33              6.16              7.79
# 1               1.60             34.40              8.71             55.04
# 2               0.50             33.00              8.36             16.50
# 3               0.95             39.81             10.09             37.82
# 4               1.32             37.85              9.59             49.96
#
#    Yield(%)  HMW(%)  Purity(%)  LMW(%)  HCP(ppm)  HCD(ppb)  Unnamed: 15
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(x="Elution pH", y="Yield(%)",
            hue="Elution_AmSo4(M)", data=df)
# Out:
# <AxesSubplot:xlabel='Elution pH', ylabel='Yield(%)'>

# %%
df2 = df[['Wash_AmSo4(M)','Elution pH','Elution_AmSo4(M)','Yield(%)','Purity(%)', 'HCP(ppm)','HCD(ppb)']]

# %%
sns.pairplot(df2, hue="Elution pH")
