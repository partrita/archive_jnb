# %%
import pandas as pd

df = pd.read_csv('.\INPUT\\0404_PB101_Bioreactor.csv', index_col=0)
df.tail()
# Out:
#             Day  Time(Hour)  Temp(C)  DO(%)  Air(mL/min)    pH  \
# Date
# 2021-03-22   12         282       33     30           10  7.21
# 2021-03-23   13         306       33     30           10  7.23
# 2021-03-24   14         330       33     30           10  7.26
# 2021-03-25   15         354       33     30           10  7.27
# 2021-03-26   16         378       33     30           10  7.20
#
#             Agitation speed(rpm)  Glucose(g/L)  Lactate(g/L)  \
# Date
# 2021-03-22                   200          7.98          0.46
# 2021-03-23                   200          6.50          0.24
# 2021-03-24                   200          5.60          0.24
# 2021-03-25                   200          3.83          0.16
# 2021-03-26                   200          7.78          0.19
#
#             Glutamine(mmol/L)  Ammonium(mmol/L)  Cell density(x10⁶cells/mL)  \
# Date
# 2021-03-22               2.81             4.602                        6.13
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

plt.figure(figsize=(10,10))

ax1 = plt.subplot(411)
ax1 = plt.plot(df['Day'], df['Temp(C)'], marker='o')

ax2 = plt.subplot(412)
ax2 = plt.plot(df['Day'], df['Temp(C)'])

ax3 = plt.subplot(413)
ax3 = plt.plot(df['Day'], df['Temp(C)'])

ax4 = plt.subplot(414)
ax4 = plt.plot(df['Day'], df['Temp(C)'])

# # Create two subplots and unpack the output array immediately
f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 2, sharey=True)
# ax1.plot(x, y)
# ax1.set_title('Sharing Y axis')
# ax2.scatter(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-3a809a0b6901> in <module>
#      18
#      19 # # Create two subplots and unpack the output array immediately
# ---> 20 f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 2, sharey=True)
#      21 # ax1.plot(x, y)
#      22 # ax1.set_title('Sharing Y axis')
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, sharex=True, figsize=(10,10))
ax1.plot(df['Day'], df['Temp(C)'], marker='o')
# ax1.set_title('Temp shift')
ax1.set_ylabel('Temp(C)')

ax2.plot(df['Day'], df['DO(%)'], marker='o')
# ax2.set_title('Temp shift')
ax2.set_ylabel('DO(%)')

ax3.plot(df['Day'], df['pH'], marker='o')
# ax3.set_title('Temp shift')
ax3.set_ylabel('pH')

ax4.plot(df['Day'], df['Air(mL/min)'], marker='o')
# ax4.set_title('Temp shift')
ax4.set_ylabel('Air(mL/min)')
# Out:
# Text(0, 0.5, 'Air(mL/min)')

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, sharex=True, figsize=(10,10))
ax1.plot(df['Day'], df['Glucose(g/L)'], marker='o')
# ax1.set_title('Temp shift')
ax1.set_ylabel('Glucose(g/L)')

ax2.plot(df['Day'], df['Lactate(g/L)'], marker='o')
# ax2.set_title('Temp shift')
ax2.set_ylabel('Lactate(g/L)')

ax3.plot(df['Day'], df['Glutamine(mmol/L)'], marker='o')
# ax3.set_title('Temp shift')
ax3.set_ylabel('Glutamine(mmol/L)')

ax4.plot(df['Day'], df['Ammonium(mmol/L)'], marker='o')
# ax4.set_title('Temp shift')
ax4.set_ylabel('Ammonium(mmol/L)')
# Out:
# Text(0, 0.5, 'Ammonium(mmol/L)')

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, sharex=True, figsize=(10,10))

ax1.plot(df['Day'], df['Temp(C)'], marker='o')
# ax1.set_title('Temp shift')
ax1.set_ylabel('Temp(C)')

ax2.plot(df['Day'], df['Cell density(x10⁶cells/mL)'], marker='o')
# ax2.set_title('Temp shift')
ax2.set_ylabel('Cell density(x10⁶cells/mL)')

ax3.plot(df['Day'], df['Cell viability(%)'], marker='o')
# ax3.set_title('Temp shift')
ax3.set_ylabel('Cell viability(%)')
ax3.set_ylim(80,100)
ax4.plot(df['Day'], df['Titer(g/L)'], marker='o')
# ax4.set_title('Temp shift')
ax4.set_ylabel('Titer(g/L)')
# Out:
# Text(0, 0.5, 'Titer(g/L)')
