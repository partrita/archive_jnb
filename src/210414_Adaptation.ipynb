# %%
import pandas as pd

df_hek = pd.read_csv('.\INPUT\\0414_HEK293.csv')
df_hek


df_chok1 = pd.read_csv('.\INPUT\\0414_CHOK1.csv')
# df_chok1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
f, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(x="Passage", y="Cell viability (%)",
                hue="FBS conc.",
                sizes=(1, 8), linewidth=0,
                data=df_hek, ax=ax)
# Out:
# <AxesSubplot:xlabel='Passage', ylabel='Cell viability (%)'>

# %%
sns.relplot(x="Passage", y="Cell viability (%)", hue="FBS conc.", kind="line", data=df_hek)

# %%
df_chok1
# Out:
#           Date   Day Cell type  Temp (°C)  CO₂ (%)  Shaking speed (rpm)  \
# 0   2021-03-29   0.0    CHO-K1       37.0      5.0                130.0
# 1   2021-03-30   1.0    CHO-K1       37.0      5.0                130.0
# 2   2021-03-31   2.0    CHO-K1       37.0      5.0                130.0
# 3   2021-04-01   3.0    CHO-K1       37.0      5.0                130.0
# 4   2021-04-01   0.0    CHO-K1       37.0      5.0                130.0
# 5   2021-04-02   1.0    CHO-K1       37.0      5.0                 90.0
# 6   2021-04-05   4.0    CHO-K1       37.0      5.0                 90.0
# 7   2021-04-09   0.0    CHO-K1       37.0      5.0                 90.0
# 8   2021-04-12   3.0    CHO-K1       37.0      5.0                 90.0
# 9   2021-04-12   3.0    CHO-K1       37.0      5.0                 90.0
# 10  2021-03-29   0.0    CHO-K1       37.0      5.0                130.0
# 11  2021-03-30   1.0    CHO-K1       37.0      5.0                130.0
# 12  2021-03-31   2.0    CHO-K1       37.0      5.0                130.0
# 13  2021-04-01   3.0    CHO-K1       37.0      5.0                130.0
# 14  2021-04-01   3.0    CHO-K1       37.0      5.0                130.0
# 15  2021-04-02   6.0    CHO-K1       37.0      5.0                 90.0
# 16  2021-04-05   9.0    CHO-K1       37.0      5.0                 90.0
# 17  2021-04-05   9.0    CHO-K1       37.0      5.0                 90.0
# 18  2021-04-07  11.0    CHO-K1       37.0      5.0                 90.0
# 19  2021-04-07  11.0    CHO-K1       37.0      5.0                 90.0
# 20  2021-04-09  13.0    CHO-K1       37.0      5.0                 90.0
# 21  2021-04-09  13.0    CHO-K1       37.0      5.0                 90.0
# 22  2021-04-12  16.0    CHO-K1       37.0      5.0                 90.0
# 23  2021-03-29   0.0    CHO-K1       37.0      5.0                130.0
# 24  2021-03-30   1.0    CHO-K1       37.0      5.0                130.0
# 25  2021-03-31   2.0    CHO-K1       37.0      5.0                130.0
# 26  2021-04-01   3.0    CHO-K1       37.0      5.0                130.0
# 27  2021-04-01   3.0    CHO-K1       37.0      5.0                130.0
# 28  2021-04-02   6.0    CHO-K1       37.0      5.0                 90.0
# 29  2021-04-05   9.0    CHO-K1       37.0      5.0                 90.0
# 30  2021-04-05   9.0    CHO-K1       37.0      5.0                 90.0
# 31  2021-04-07  11.0    CHO-K1       37.0      5.0                 90.0
# 32  2021-04-07  11.0    CHO-K1       37.0      5.0                 90.0
# 33  2021-04-09  13.0    CHO-K1       37.0      5.0                 90.0
# 34  2021-04-09  13.0    CHO-K1       37.0      5.0                 90.0
# 35  2021-04-12  16.0    CHO-K1       37.0      5.0                 90.0
# 36         NaN   NaN       NaN        NaN      NaN                  NaN
# 37         NaN   NaN       NaN        NaN      NaN                  NaN
# 38         NaN   NaN       NaN        NaN      NaN                  NaN
# 39         NaN   NaN       NaN        NaN      NaN                  NaN
# 40         NaN   NaN       NaN        NaN      NaN                  NaN
# 41         NaN   NaN       NaN        NaN      NaN                  NaN
# 42         NaN   NaN       NaN        NaN      NaN                  NaN
# 43         NaN   NaN       NaN        NaN      NaN                  NaN
# 44         NaN   NaN       NaN        NaN      NaN                  NaN
# 45         NaN   NaN       NaN        NaN      NaN                  NaN
# 46         NaN   NaN       NaN        NaN      NaN                  NaN
# 47         NaN   NaN       NaN        NaN      NaN                  NaN
#
#    VCD (x10⁶cells/mL) Cell viability (%)  Working Volume (mL)  Passage  \
# 0                   .                  .                 30.0      1.0
# 1                0.31                 58                 30.0      1.0
# 2                0.06                  6                 30.0      1.0
# 3                0.01                  2                 30.0      1.0
# 4                 NaN                NaN                 30.0      1.0
# 5                0.02                 57                 50.0      1.0
# 6                   0                  0                 50.0      1.0
# 7                 0.5                 93                 30.0      1.0
# 8                0.55                 78                 30.0      1.0
# 9                0.55                 78                 30.0      2.0
# 10                  .                  .                 30.0      1.0
# 11               0.32                 61                 30.0      1.0
# 12               0.31                 60                 30.0      1.0
# 13               0.29                 56                 30.0      1.0
# 14               0.29                 56                 30.0      1.0
# 15               0.13                 76                 50.0      1.0
# 16               0.25                 93                 50.0      3.0
# 17               0.25                 93                 50.0      3.0
# 18                0.2                 85                 30.0      5.0
# 19                0.2                 85                 30.0      6.0
# 20               0.19                 89                 30.0      6.0
# 21               0.19                 89                 30.0      7.0
# 22              0.006                  5                 30.0      7.0
# 23                  .                  .                 30.0      1.0
# 24               0.62                 83                 30.0      1.0
# 25               0.37                 84                 30.0      1.0
# 26               0.31                 68                 30.0      2.0
# 27               0.31                 68                 30.0      2.0
# 28               0.25                 98                 50.0      3.0
# 29               0.48                 91                 50.0      3.0
# 30               0.48                 91                 50.0      3.0
# 31               0.49                 93                 50.0      3.0
# 32               0.49                 93                 30.0      4.0
# 33               0.66                 98                 30.0      4.0
# 34               0.66                 98                 30.0      4.0
# 35              0.017                  3                 30.0      5.0
# 36                NaN                NaN                  NaN      NaN
# 37                NaN                NaN                  NaN      NaN
# 38                NaN                NaN                  NaN      NaN
# 39                NaN                NaN                  NaN      NaN
# 40                NaN                NaN                  NaN      NaN
# 41                NaN                NaN                  NaN      NaN
# 42                NaN                NaN                  NaN      NaN
# 43                NaN                NaN                  NaN      NaN
# 44                NaN                NaN                  NaN      NaN
# 45                NaN                NaN                  NaN      NaN
# 46                NaN                NaN                  NaN      NaN
# 47                NaN                NaN                  NaN      NaN
#
#     FBS conc.                                        Comments
# 0        0.00                           adherent → suspension
# 1        0.00                                             NaN
# 2        0.00                                             NaN
# 3        0.00                                      Cell death
# 4        0.00   adherent → suspension (anti clumping reagent)
# 5        0.00                                             NaN
# 6        0.00                                      Cell death
# 7        1.25                                             NaN
# 8        1.25                                             NaN
# 9        1.50            Cell culture (anti clumping reagent)
# 10       2.50                           adherent → suspension
# 11       2.50                                             NaN
# 12       2.50                                             NaN
# 13       2.50                                      Cell death
# 14       2.50   adherent → suspension (anti clumping reagent)
# 15       2.50                                             NaN
# 16       2.50                                             NaN
# 17       2.50  Cell culture (trypsin & anti clumping reagent)
# 18       2.50                                             NaN
# 19       2.50            Cell culture (anti clumping reagent)
# 20       2.50                                             NaN
# 21       2.50            Cell culture (anti clumping reagent)
# 22       2.50                                              폐기
# 23       5.00                                             NaN
# 24       5.00                                             NaN
# 25       5.00                                             NaN
# 26       5.00                                             NaN
# 27       5.00                                             NaN
# 28       5.00                                             NaN
# 29       5.00                                             NaN
# 30       5.00  Cell culture (trypsin & anti clumping reagent)
# 31       5.00                                             NaN
# 32       5.00            Cell culture (anti clumping reagent)
# 33       5.00                                             NaN
# 34       5.00            Cell culture (anti clumping reagent)
# 35       5.00                                              폐기
# 36        NaN                                             NaN
# 37        NaN                                             NaN
# 38        NaN                                             NaN
# 39        NaN                                             NaN
# 40        NaN                                             NaN
# 41        NaN                                             NaN
# 42        NaN                                             NaN
# 43        NaN                                             NaN
# 44        NaN                                             NaN
# 45        NaN                                             NaN
# 46        NaN                                             NaN
# 47        NaN                                             NaN

# %%
f, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(x="Passage", y="Cell viability (%)",
                hue="FBS conc.",
                sizes=(1, 8), linewidth=0,
                data=df_chok1, ax=ax)
# Out:
# <AxesSubplot:xlabel='Passage', ylabel='Cell viability (%)'>

# %%
sns.relplot(x="Passage", y="Cell viability (%)", hue="FBS conc.", kind="line", data=df_chok1)
