# %%
import matplotlib.pyplot as plt


plt.subplot(2, 2, 1)
plt.title('First Title')

plt.subplot(2, 2, 2)
plt.title('Second Title')

plt.subplot(2, 2, 3)
plt.title('Third Title')

plt.subplot(2, 2, 4)
plt.title('Fourth Title')

plt.tight_layout()
plt.show()

# %%
import pandas as pd

df = pd.read_csv('.\INPUT\\0503_Bioreactor.csv')
df.tail()
# Out:
#     Day  Temp(°C)  DO(%)     pH  Glucose(g/L)  Lactate(g/L)  \
# 8     8        33     36  7.139         5.999         0.281
# 9     9        33     38  7.187         8.012         0.117
# 10   10        33     48  7.197         6.824         0.216
# 11   11        33     30  7.155         7.346         0.173
# 12   12        33     30  7.205         5.342         0.194
#
#     Glutamine(mmol/L)  Ammonium (mmol/L)  Cell density(x10⁶cells/mL)  \
# 8                3.01              4.295                       15.60
# 9                4.27              6.069                       17.20
# 10               5.13              8.444                       14.15
# 11               5.49              8.498                       14.20
# 12               6.15              9.420                       14.65
#
#     Cell viability (%)  Titer(g/L)  pCO₂    pO₂
# 8                   97       1.420  75.9  105.7
# 9                   94       1.750  75.3   98.2
# ...

# %%
f, ((ax1, ax2, ax3, ax4),(ax5, ax6, ax7, ax8))  = plt.subplots(4, 2, sharex=True, figsize=(10,10))
ax1.plot(df['Day'], df['Temp(°C)'], marker='o')
# ax1.set_title('Temp shift')
ax1.set_ylabel('Temp(°C)')

ax2.plot(df['Day'], df['DO(%)'], marker='o')
# ax2.set_title('Temp shift')
ax2.set_ylabel('DO(%)')

ax3.plot(df['Day'], df['pH'], marker='o')
# ax3.set_title('Temp shift')
ax3.set_ylabel('pH')

ax5.plot(df['Day'], df['Temp(°C)'], marker='o')
# ax1.set_title('Temp shift')
ax5.set_ylabel('Temp(°C)')

ax6.plot(df['Day'], df['DO(%)'], marker='o')
# ax2.set_title('Temp shift')
ax6.set_ylabel('DO(%)')

ax7.plot(df['Day'], df['pH'], marker='o')
# ax3.set_title('Temp shift')
ax7.set_ylabel('pH')

ax8.plot(df['Day'], df['pH'], marker='o')
# ax3.set_title('Temp shift')
ax8.set_ylabel('pH')



plt.xlabel('Day')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-160777ff3741> in <module>
# ----> 1 f, ((ax1, ax2, ax3, ax4),(ax5, ax6, ax7, ax8))  = plt.subplots(4, 2, sharex=True, figsize=(10,10))
#       2 ax1.plot(df['Day'], df['Temp(°C)'], marker='o')
#       3 # ax1.set_title('Temp shift')
#       4 ax1.set_ylabel('Temp(°C)')
#       5
#
# ValueError: too many values to unpack (expected 2)

# %%
import seaborn as sns; sns.set()
import numpy as np

plt.figure(figsize=(10, 10))

plt.subplot(221)
plt.plot(df['Day'], df['Titer(g/L)'], marker='o', color='k')
plt.xlabel('Day')
plt.ylabel('Titer(g/L)')

plt.subplot(427)
plt.plot(df['Day'], df['Cell density(x10⁶cells/mL)'], marker='o', color='k')
plt.xlabel('Day')
plt.ylabel('VCD(x10⁶cells/mL)')
# plt.subplot(423)

plt.subplot(425)
plt.plot(df['Day'], df['Cell viability (%)'], marker='o', color='k')
plt.xlabel('Day')
plt.ylabel('Viability(%)')

plt.subplot(422)
plt.plot(df['Day'], df['Glucose(g/L)'], marker='o')
plt.xlabel('Day')
plt.ylabel('Glucose(g/L)')

plt.subplot(424)
plt.plot(df['Day'], df['Lactate(g/L)'], marker='o')
plt.xlabel('Day')
plt.ylabel('Lactate(g/L)')

plt.subplot(426)
plt.plot(df['Day'], df['Glutamine(mmol/L)'], marker='o')
plt.xlabel('Day')
plt.ylabel('Glutamine(mmol/L)')

plt.subplot(428)
plt.plot(df['Day'], df['Ammonium (mmol/L)'], marker='o')
plt.xlabel('Day')
plt.ylabel('Ammonium (mmol/L)')

plt.tight_layout(pad=0.7)
plt.show()
