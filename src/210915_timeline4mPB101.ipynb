# %%
sessionInfo()[[1]]$version.string
# Out:
# [1] "R version 3.6.3 (2020-02-29)"

# %%
library("ganttrify")
df = ganttrify::test_project
df
# Out:
#    wp                         activity                    start_date end_date
# 1  WP1 - Whatever admin       1.1. That admin activity     1          6
# 2  WP1 - Whatever admin       1.2. Another admin activity  3          6
# 3  WP1 - Whatever admin       1.3. Fancy admin activity    4          7
# 4  WP2 - Whatever actual work 2.1. Actual stuff            5         10
# 5  WP2 - Whatever actual work 2.2. Actual R&D stuff        6         12
# 6  WP2 - Whatever actual work 2.3. Really real research    9         12
# 7  WP2 - Whatever actual work 2.4. Ethics!                 3          5
# 8  WP2 - Whatever actual work 2.4. Ethics!                 8          9
# 9  WP3 - Dissemination        3.1. Disseminate near        6          9
# 10 WP3 - Dissemination        3.1. Disseminate near       12         12
# 11 WP3 - Dissemination        3.2. Disseminate far         8         12

# %%
wp <- c(
    'Research','Data preparation','Analyses','Plan','Introduction','Methods',
    'Results','Discussion','Conclusion','Preliminary version to co-authors')

# %%
activity <- c(
    'readings','preparation','nalyses','lan','ntroduction','ethods',
    'esults','Dscussion','Cnclusion','Prliminary version to co-authors')

# %%
start_date <- c(
    '2017-09-01','2017-09-14','2017-09-28','2017-09-21','2017-09-28',
    '2017-09-14','2017-10-28','2017-11-14','2017-11-28','2017-12-11')

# %%
end_date <- c(
    '2017-11-28','2017-09-28','2017-10-28','2017-09-28','2017-10-28',
    '2017-10-28','2017-11-14','2017-11-28','2017-12-04','2017-12-11')

# %%
df <- data.frame(wp = wp,
                 activity = activity,
                 start_date = start_date,
                 end_date = end_date)

df
# Out:
#    wp                                activity
# 1  Research                          readings
# 2  Data preparation                  preparation
# 3  Analyses                          nalyses
# 4  Plan                              lan
# 5  Introduction                      ntroduction
# 6  Methods                           ethods
# 7  Results                           esults
# 8  Discussion                        Dscussion
# 9  Conclusion                        Cnclusion
# 10 Preliminary version to co-authors Prliminary version to co-authors
#    start_date end_date
# 1  2017-09-01 2017-11-28
# 2  2017-09-14 2017-09-28
# 3  2017-09-28 2017-10-28
# 4  2017-09-21 2017-09-28
# 5  2017-09-28 2017-10-28
# 6  2017-09-14 2017-10-28
# 7  2017-10-28 2017-11-14
# 8  2017-11-14 2017-11-28
# 9  2017-11-28 2017-12-04
# 10 2017-12-11 2017-12-11

# %%
# Out:
#    wp                                activity
# 1  Research                          readings
# 2  Data preparation                  preparation
# 3  Analyses                          nalyses
# 4  Plan                              lan
# 5  Introduction                      ntroduction
# 6  Methods                           ethods
# 7  Results                           esults
# 8  Discussion                        Dscussion
# 9  Conclusion                        Cnclusion
# 10 Preliminary version to co-authors Prliminary version to co-authors
#    start_date end_date
# 1  2017-09-01 2017-11-28
# 2  2017-09-14 2017-09-28
# 3  2017-09-28 2017-10-28
# 4  2017-09-21 2017-09-28
# 5  2017-09-28 2017-10-28
# 6  2017-09-14 2017-10-28
# 7  2017-10-28 2017-11-14
# 8  2017-11-14 2017-11-28
# 9  2017-11-28 2017-12-04
# 10 2017-12-11 2017-12-11

# %%
ganttrify(project = df,
          project_start_date = "2021-01",
          hide_wp = TRUE,
#           line_end = "butt",
          alpha_activity = 0.8,
#           font_family = "NanumGothic"
         )
# Out:
# plot without title

# %%
windowsFonts(Arial=windowsFont("TT Arial"))
windowsFonts(RobotoCondensed=windowsFont("RobotoCondensed"))

# %%
systemfonts::system_fonts()
# Out:
#     path
# 1   C:\\WINDOWS\\Fonts\\arial.ttf
# 2   C:\\WINDOWS\\Fonts\\ariblk.ttf
# 3   C:\\WINDOWS\\Fonts\\arialbd.ttf
# 4   C:\\WINDOWS\\Fonts\\arialbi.ttf
# 5   C:\\WINDOWS\\Fonts\\ariali.ttf
# 6   C:\\WINDOWS\\Fonts\\bahnschrift.ttf
# 7   C:\\WINDOWS\\Fonts\\calibri.ttf
# 8   C:\\WINDOWS\\Fonts\\calibrib.ttf
# 9   C:\\WINDOWS\\Fonts\\calibriz.ttf
# 10  C:\\WINDOWS\\Fonts\\calibrii.ttf
# 11  C:\\WINDOWS\\Fonts\\calibril.ttf
# 12  C:\\WINDOWS\\Fonts\\calibrili.ttf
# 13  C:\\WINDOWS\\Fonts\\cambria.ttc
# 14  C:\\WINDOWS\\Fonts\\cambria.ttc
# 15  C:\\WINDOWS\\Fonts\\cambriab.ttf
# 16  C:\\WINDOWS\\Fonts\\cambriaz.ttf
# 17  C:\\WINDOWS\\Fonts\\cambriai.ttf
# 18  C:\\WINDOWS\\Fonts\\candara.ttf
# 19  C:\\WINDOWS\\Fonts\\candarab.ttf
# 20  C:\\WINDOWS\\Fonts\\candaraz.ttf
# 21  C:\\WINDOWS\\Fonts\\candarai.ttf
# 22  C:\\WINDOWS\\Fonts\\candaral.ttf
# 23  C:\\WINDOWS\\Fonts\\candarali.ttf
# 24  C:\\WINDOWS\\Fonts\\comic.ttf
# 25  C:\\WINDOWS\\Fonts\\comicbd.ttf
# ...

# %% [markdown]
# https://github.com/giocomai/ganttrify

# %%
# exceldata = read_excel("C:\\tutorialkart\\r\\sample.xlsx")
# dfdata = data.frame(exceldata)

# data <- read.csv('testfile.csv')
data <- read.csv("http://faculty.marshall.usc.edu/gareth-james/ISL/Advertising.csv")
# Out:
# Warning message in file(file, "rt"):
# "cannot open URL 'http://faculty.marshall.usc.edu/gareth-james/ISL/Advertising.csv': HTTP status was '404 Not Found'"
# Error in file(file, "rt"): 커넥션을 열 수 없습니다
# Traceback:
#
# 1. read.csv("http://faculty.marshall.usc.edu/gareth-james/ISL/Advertising.csv")
# 2. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)
# 3. file(file, "rt")
