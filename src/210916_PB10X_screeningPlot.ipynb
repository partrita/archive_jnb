# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
import pandas as pd

df = pd.read_csv('./INPUT/210916_PB10X.csv')
df
# Out:
#        name category                               construct  Titer(g/L)  \
# 0    H-11A1    PB10X                                   PB101       0.501
# 1   H-01C52    PB10X         PB101-NH20_nonglycosylation(NG)       0.221
# 2   H-01C55    PB10X                            NH20_GS+IgG1       0.283
# 3   H-01C56    PB10X                               NH36_modi       0.095
# 4   H-01C57    PB10X                             vector seq1       0.223
# 5   H-01C58    PB10X                             vector seq2       0.304
# 6   H-01C59    PB10X                             vector seq3       0.303
# 7   H-01C60    PB10X                             vector seq4       0.259
# 8    H-12B1    PB20X                       Panitumumab-PB101       0.161
# 9   H-12C25    PB20X                v1/ori/none/none/H-01C27       0.219
# 10  H-12C26    PB20X               v1/NH29/none/none/H-01C27       0.197
# 11  H-12C27    PB20X               v2/NH29/none/none/H-01C27       0.223
# ...

# %%
df.columns
# Out:
# Index(['name', 'category', 'construct', 'Titer(g/L)', 'Volume',
#        'Load amounts\n(mg)', 'Eluate amounts\n(mg)', 'Step yield\n(%)',
#        'HMWS\n(%)', 'Monomer\n(%)', 'LMWS\n(%)'],
#       dtype='object')

# %%
df[['name', 'category', 'construct', 'Load amounts\n(mg)', 'Eluate amounts\n(mg)', 'Step yield\n(%)',
       'HMWS\n(%)', 'Monomer\n(%)', 'LMWS\n(%)']]
# Out:
#        name category                               construct  \
# 0    H-11A1    PB10X                                   PB101
# 1   H-01C52    PB10X         PB101-NH20_nonglycosylation(NG)
# 2   H-01C55    PB10X                            NH20_GS+IgG1
# 3   H-01C56    PB10X                               NH36_modi
# 4   H-01C57    PB10X                             vector seq1
# 5   H-01C58    PB10X                             vector seq2
# 6   H-01C59    PB10X                             vector seq3
# 7   H-01C60    PB10X                             vector seq4
# 8    H-12B1    PB20X                       Panitumumab-PB101
# 9   H-12C25    PB20X                v1/ori/none/none/H-01C27
# 10  H-12C26    PB20X               v1/NH29/none/none/H-01C27
# 11  H-12C27    PB20X               v2/NH29/none/none/H-01C27
# 12  H-12C28    PB20X           v1/NH29/G44C/Q(G)100C/H-01C27
# 13  H-12C29    PB20X              v1/NH29/Q105C/K42C/H-01C27
# ...

# %%
df_pb10x = df[df['category']=='PB10X']
df_pb20x = df[df['category']=='PB20X']

# %%
plt.style.use(['ggplot'])
plt.figure(figsize=(10,6))
plt.ylim(0,14)
plt.bar(df_pb10x['name'],df_pb10x['Eluate amounts\n(mg)'])
# Out:
# <BarContainer object of 8 artists>

# %%
plt.style.use(['ggplot'])
plt.figure(figsize=(10,6))
plt.ylim(0,14)
plt.bar(df_pb20x['name'],df_pb20x['Eluate amounts\n(mg)'])
# Out:
# <BarContainer object of 10 artists>

# %%
f, ax = plt.subplots(figsize=(6, 15))
crashes = df.sort_values("Monomer\n(%)", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(y="name", x="Monomer\n(%)", data=crashes,
            label="Monomer", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(y="name", x="HMWS\n(%)", data=crashes,
            label="HMWs", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(
#     xlim=(0, 24),
       ylabel="",
       xlabel="")
sns.despine(left=True, bottom=True)

# %%
plt.style.use(['ggplot'])
f, ax = plt.subplots(figsize=(6, 15))
crashes = df

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(y="name", x="Monomer\n(%)", data=crashes,
            label="Monomer", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(y="name", x="HMWS\n(%)", data=crashes,
            label="HMWs", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(
#     xlim=(0, 24),
       ylabel="",
       xlabel="")
sns.despine(left=True, bottom=True)

# %%
f, ax = plt.subplots(figsize=(6, 7))
crashes = df_pb10x.sort_values("Monomer\n(%)", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(y="name", x="Monomer\n(%)", data=crashes,
            label="Monomer", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(y="name", x="HMWS\n(%)", data=crashes,
            label="HMWs", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(
#     xlim=(0, 24),
       ylabel="",
       xlabel="")
sns.despine(left=True, bottom=True)

# %%
f, ax = plt.subplots(figsize=(6, 7))
crashes = df_pb20x.sort_values("Monomer\n(%)", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(y="name", x="Monomer\n(%)", data=crashes,
            label="Monomer", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(y="name", x="HMWS\n(%)", data=crashes,
            label="HMWs", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(
#     xlim=(0, 24),
       ylabel="",
       xlabel="")
sns.despine(left=True, bottom=True)
