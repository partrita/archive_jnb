# %%
import pandas as pd

df = pd.read_csv("./INPUT/220106_D20A_CTDM3_Tracker.csv", index_col=0)
df.head()
# Out:
#                                                     1st Review  2ed Review  \
# Module
# 3.2.S.1.1 Nomenclature                                     100         100
# 3.2.S.1.2 Structure                                          0           0
# 3.2.S.1.3 General Properties                                 0           0
# 3.2.S.2.1 Manufacturer(s)                                  100         100
# 3.2.S.2.2 Description of Manufacturing Process ...           0           0
#
#                                                     Finalize
# Module
# 3.2.S.1.1 Nomenclature                                     0
# 3.2.S.1.2 Structure                                        0
# 3.2.S.1.3 General Properties                               0
# 3.2.S.2.1 Manufacturer(s)                                  0
# 3.2.S.2.2 Description of Manufacturing Process ...         0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(5,10))
ax = sns.heatmap(df, cmap="YlGnBu",cbar=False)

# %%
cmap = sns.light_palette("#2ecc71", as_cmap=True)
df = pd.read_csv("./INPUT/220106_D20A_CTDM3_Tracker.csv", index_col=0)
plt.figure(figsize=(4,10))
ax = sns.heatmap(df, cmap=cmap, cbar=False)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("./INPUT/220117_D20A_CTDM3_Tracker.csv", index_col=0)

cmap = sns.light_palette("#2ecc71", as_cmap=True)

plt.figure(figsize=(4,10))
ax = sns.heatmap(df, cmap=cmap, cbar=False)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("./INPUT/220124_D20A_CTDM3_Tracker.csv", index_col=0)

cmap = sns.light_palette("#2ecc71", as_cmap=True)

plt.figure(figsize=(4,10))
ax = sns.heatmap(df, cmap=cmap, cbar=False)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("./INPUT/220207_D20A_CTDM3_Tracker.csv", index_col=0)

cmap = sns.light_palette("#2ecc71", as_cmap=True)

plt.figure(figsize=(4,10))
ax = sns.heatmap(df, cmap=cmap, cbar=False)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("./INPUT/220211_D20A_CTDM3_Tracker.csv", index_col=0)

cmap = sns.light_palette("#2ecc71", as_cmap=True)

plt.figure(figsize=(4,10))
ax = sns.heatmap(df, cmap=cmap, cbar=False)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("./INPUT/220221_D20A_CTDM3_Tracker.csv", index_col=0)

cmap = sns.light_palette("#2ecc71", as_cmap=True)

plt.figure(figsize=(4,10))
ax = sns.heatmap(df, cmap=cmap, cbar=False)
