# %% [markdown]
# # PB101 stability test plotting

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
# (style="ticks")
sns.set_style("darkgrid")

df = pd.read_csv("./INPUT/220324_PB101_Stability_2.csv", index_col=None)
df.head()
# Out:
#     Grade Product type StorageTemp  TimePoint(months)  SE-HPLC(monomer%)  \
# 0  NonGMP           DS    (-70±10)                  0              99.16
# 1  NonGMP           DS    (-70±10)                  1              99.16
# 2  NonGMP           DS    (-70±10)                  3              99.06
# 3  NonGMP           DS    (-70±10)                  6              99.03
# 4  NonGMP           DS    (-70±10)                  9                NaN
#
#    Potency(%)
# 0       108.0
# 1       100.0
# 2       104.0
# 3        96.0
# 4         NaN

# %%
df.columns
# Out:
# Index(['Grade', 'Product type', 'StorageTemp', 'TimePoint(months)',
#        'SE-HPLC(monomer%)', 'Potency(%)'],
#       dtype='object')

# %%
df_nonGMP = df[df['Grade'] == "NonGMP"]
df_GMP = df[df['Grade'] == "GMP"]

df_GMP.head()
# Out:
#    Grade Product type StorageTemp  TimePoint(months)  SE-HPLC(monomer%)  \
# 22   GMP           DS    (-70±10)                  0               99.0
# 23   GMP           DS    (-70±10)                  1               99.0
# 24   GMP           DS    (-70±10)                  3                NaN
# 25   GMP           DS    (-70±10)                  6                NaN
# 26   GMP           DS    (-70±10)                  9                NaN
#
#     Potency(%)
# 22       103.0
# 23       105.0
# 24         NaN
# 25         NaN
# 26         NaN

# %%
g = sns.lmplot(x="TimePoint(months)", y="Potency(%)", col="StorageTemp", hue="Grade", data=df,
           col_wrap=3, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 0.8}
          )
g.set(xlim=(-1, 12), ylim=(60, 140),
#       xticks=[10, 30, 50], yticks=[2, 6, 10]
     )
# g.map(plt.axhline, y=70, ls='--', c='red')

# %%
g = sns.lmplot(x="TimePoint(months)", y="SE-HPLC(monomer%)", col="StorageTemp", hue="Grade", data=df,
           col_wrap=3, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 0.8}
          )
g.set(xlim=(-1, 12), ylim=(90, 100),
#       xticks=[10, 30, 50],
      yticks=[90,95,100]
     )
# g.map(plt.axhline, y=95, ls='--', c='red')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv("./INPUT/0329_PB101_StabilityTest_Summary.csv", index_col=None)
df.head()
# Out:
#   Product type Lot No.  Condition      Temp  cycle  Time\nPoint        Date  \
# 0    NonGMP-DS  D20A01  Long-term  (-70±10)    NaN          0.0  2021-05-20
# 1    NonGMP-DS  D20A01  Long-term  (-70±10)    NaN          1.0  2021-06-20
# 2    NonGMP-DS  D20A01  Long-term  (-70±10)    NaN          3.0  2021-09-20
# 3    NonGMP-DS  D20A01  Long-term  (-70±10)    NaN          6.0  2021-11-20
# 4    NonGMP-DS  D20A01  Long-term  (-70±10)    NaN          9.0  2022-02-20
#
#   Color  Clearity Visible\nparticle  ...  CE-SDS(NR)\n_HMWs CE-SDS(NR)\n_LMWs  \
# 0    B7  4.45 NTU               NaN  ...                 ND              0.37
# 1    B7  4.32 NTU               NaN  ...                 ND              0.39
# 2    B7  4.30 NTU               NaN  ...                 ND              0.34
# 3    B7  4.29 NTU               NaN  ...                 ND              0.56
# 4   NaN       NaN               NaN  ...                NaN               NaN
#
#    CE-SDS(R)\n_Purity  CE-SDS(R)\n_HMWs  CE-SDS(R)\n_LMWs  Potency   pH  \
# 0                97.0                ND              2.52    108.0  5.5
# 1                97.0                ND              2.62    100.0  5.5
# 2                97.0                ND              2.70    104.0  5.5
# 3                97.0                ND              2.82     96.0  5.5
# 4                 NaN               NaN               NaN      NaN  NaN
#
#    Osmolality   PS80 Sub-visible\nparticle
# 0       629.0  0.061                   NaN
# 1       637.0  0.060                   NaN
# 2       635.0  0.068                   NaN
# 3       637.0  0.063                   NaN
# 4         NaN    NaN                   NaN
#
# [5 rows x 26 columns]

# %%
g = sns.lmplot(x="Time\nPoint", y="Potency", col="Temp", hue="Product type", data=df,
           col_wrap=2, ci=None, palette="muted", height=4, scatter_kws={"s": 50, "alpha": 0.8})
g.set(xlim=(-1, 12), ylim=(0, 120))

# %%
g = sns.lmplot(x="Time\nPoint", y="SE-HPLC\n(monomer)", col="Temp", hue="Product type", data=df,
           col_wrap=2, ci=None, palette="muted", height=4, scatter_kws={"s": 50, "alpha": 0.8})
g.set(xlim=(-1, 12), ylim=(70, 120))

# %%
g = sns.lmplot(x="Time\nPoint", y="CE-SDS(R)\n_Purity", col="Temp", hue="Product type", data=df,
           col_wrap=2, ci=None, palette="muted", height=4, scatter_kws={"s": 50, "alpha": 0.8})
g.set(xlim=(-1, 12), ylim=(60, 120))

# %%
g = sns.lmplot(x="Time\nPoint", y="CE-SDS(NR)\n_purity", col="Temp", hue="Product type", data=df,
           col_wrap=2, ci=None, palette="muted", height=4, scatter_kws={"s": 50, "alpha": 0.8})
g.set(xlim=(-1, 12), ylim=(60, 120))

# %%
g = sns.lmplot(x="Time\nPoint", y="Protein\nConc.", col="Temp", hue="Product type", data=df,
           col_wrap=2, ci=None, palette="muted", height=4, scatter_kws={"s": 50, "alpha": 0.8})
g.set(xlim=(-1, 12), ylim=(0, 30))

# %%
g = sns.lmplot(x="Time\nPoint", y="Osmolality", col="Temp", hue="Product type", data=df,
           col_wrap=2, ci=None, palette="muted", height=4, scatter_kws={"s": 50, "alpha": 0.8})
g.set(xlim=(-1, 12), ylim=(400, 700))

# %%
g = sns.lmplot(x="Time\nPoint", y="PS80", col="Temp", hue="Product type", data=df,
           col_wrap=2, ci=None, palette="muted", height=4, scatter_kws={"s": 50, "alpha": 0.8})
g.set(xlim=(-1, 12), ylim=(0.02, 0.08))
