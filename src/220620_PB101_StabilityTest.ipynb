# %% [markdown]
# # PB101 stability test plotting

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
# (style="ticks")
sns.set_style("darkgrid")

def stability_plot(x, y, col, xlim, ylim ):
    g = sns.lmplot(x=x, y=y, col=col, hue="Product type", data=df,
           col_wrap=2, ci=None, palette="muted", height=4, scatter_kws={"s": 50, "alpha": 0.8})
    g.set(xlim=xlim, ylim=ylim)
    return g

df = pd.read_csv("./INPUT/0620_PB101_StabilityTest_Summary.csv", index_col=None)
df.head()
# Out:
#   Product type Lot No.  Condition      Temp  cycle  Time\nPoint        Date  \
# 0    NonGMP-DS  D20A01  Long-term  (-70±10)    NaN          0.0  2021-05-20
# 1    NonGMP-DS  D20A01  Long-term  (-70±10)    NaN          1.0  2021-06-20
# 2    NonGMP-DS  D20A01  Long-term  (-70±10)    NaN          3.0  2021-09-20
# 3    NonGMP-DS  D20A01  Long-term  (-70±10)    NaN          6.0  2021-11-20
# 4    NonGMP-DS  D20A01  Long-term  (-70±10)    NaN          9.0  2022-02-20
#
#   Color              Clearity Visible\nparticle  ...  CE-SDS(NR)\n_HMWs  \
# 0    B7              4.45 NTU               NaN  ...                 ND
# 1    B7              4.32 NTU               NaN  ...                 ND
# 2    B7              4.30 NTU               NaN  ...                 ND
# 3    B7              4.29 NTU               NaN  ...                 ND
# 4    B7  Slightly\nopalescent               NaN  ...                 ND
#
#   CE-SDS(NR)\n_LMWs  CE-SDS(R)\n_Purity  CE-SDS(R)\n_HMWs  CE-SDS(R)\n_LMWs  \
# 0              0.37                97.0                ND              2.52
# 1              0.39                97.0                ND              2.62
# 2              0.34                97.0                ND              2.70
# 3              0.56                97.0                ND              2.82
# 4              0.55                97.0                ND              3.27
#
#    Potency   pH  Osmolality   PS80 Sub-visible\nparticle
# 0    108.0  5.5       629.0  0.061                   NaN
# 1    100.0  5.5       637.0  0.060                   NaN
# 2    104.0  5.5       635.0  0.068                   NaN
# 3     96.0  5.5       637.0  0.063                   NaN
# 4     93.0  5.5       641.0  0.069                   NaN
#
# [5 rows x 26 columns]

# %%
stability_plot(x="Time\nPoint", y="Potency", col="Temp", xlim=(-1, 12), ylim=(0, 140))

# %%
stability_plot(x="Time\nPoint", y="SE-HPLC\n(monomer)", col="Temp", xlim=(-1, 12), ylim=(70, 120))

# %%
stability_plot(x="Time\nPoint", y="CE-SDS(R)\n_Purity", col="Temp", xlim=(-1, 12), ylim=(50, 120))
